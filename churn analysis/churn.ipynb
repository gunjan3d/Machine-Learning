# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Customer-Churn-Records.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %%
df.shape
# Out:
# (10000, 18)

# %%
df.size
# Out:
# 180000

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000

# %%
columns_to_drop = ['RowNumber','CustomerId','Surname']
df.drop(columns=columns_to_drop,axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %%
df.dtypes
# Out:
# CreditScore             int64
# Geography              object
# Gender                 object
# Age                     int64
# Tenure                  int64
# Balance               float64
# NumOfProducts           int64
# HasCrCard               int64
# IsActiveMember          int64
# EstimatedSalary       float64
# Exited                  int64
# Complain                int64
# Satisfaction Score      int64
# Card Type              object
# Point Earned            int64
# dtype: object

# %%
df['Gender'].replace({'Female':0 , 'Male':1},inplace=True)
# Out:
# C:\Users\gunja\AppData\Local\Temp\ipykernel_26168\2237275939.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace({'Female':0 , 'Male':1},inplace=True)
# C:\Users\gunja\AppData\Local\Temp\ipykernel_26168\2237275939.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender'].replace({'Female':0 , 'Male':1},inplace=True)

# %%
df.head(5)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France       0   42       2       0.00              1
# 1          608     Spain       0   41       1   83807.86              1
# 2          502    France       0   42       8  159660.80              3
# 3          699    France       0   39       1       0.00              2
# 4          850     Spain       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction Score Card Type  Point Earned
# 0                   2   DIAMOND           464
# 1                   3   DIAMOND           456
# 2                   3   DIAMOND           377
# 3                   5      GOLD           350
# 4                   5      GOLD           425

# %%
df['Geography'].value_counts()

df['Geography'].replace({'France':0,'Germany':1,'Spain':2},inplace=True)
# Out:
# C:\Users\gunja\AppData\Local\Temp\ipykernel_26168\871821995.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Geography'].replace({'France':0,'Germany':1,'Spain':2},inplace=True)
# C:\Users\gunja\AppData\Local\Temp\ipykernel_26168\871821995.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Geography'].replace({'France':0,'Germany':1,'Spain':2},inplace=True)

# %%
df.tail()
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 9995          1               0         96270.64       0         0
# 9996          1               1        101699.77       0         0
# 9997          0               1         42085.58       1         1
# 9998          1               0         92888.52       1         1
# 9999          1               0         38190.78       0         0
#
#       Satisfaction Score Card Type  Point Earned
# 9995                   1   DIAMOND           300
# 9996                   5  PLATINUM           771
# 9997                   3    SILVER           564
# 9998                   2      GOLD           339
# 9999                   3   DIAMOND           911

# %%
df.dtypes
# Out:
# CreditScore             int64
# Geography               int64
# Gender                  int64
# Age                     int64
# Tenure                  int64
# Balance               float64
# NumOfProducts           int64
# HasCrCard               int64
# IsActiveMember          int64
# EstimatedSalary       float64
# Exited                  int64
# Complain                int64
# Satisfaction Score      int64
# Card Type              object
# Point Earned            int64
# dtype: object

# %%
df = pd.get_dummies(data=df,columns=['Card Type'])

# %%
df.groupby('Age').sum()
# Out:
#      CreditScore  Geography  Gender  Tenure     Balance  NumOfProducts  \
# Age
# 18         15107         16      18     106  1741730.65             33
# 19         17972         24      18     137  1903568.57             37
# 20         26602         32      27     203  3041555.60             62
# 21         34306         33      20     253  4024124.79             88
# 22         53470         67      42     477  5729954.90            128
# ..           ...        ...     ...     ...         ...            ...
# 83           678          1       1       6   123356.63              1
# 84           945          1       1      16   180115.73              2
# 85           787          0       0      10        0.00              2
# 88           513          2       1      10        0.00              2
# 92          1458          0       2       4   247589.55              3
#
#      HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# Age
# 18          14              13       1872252.57       2         2
# 19          22              15       2638820.71       1         1
# 20          26              19       3908221.68       2         2
# 21          38              32       5434443.71       3         3
# 22          58              46       8259015.70      12        12
# ..         ...             ...              ...     ...       ...
# 83           0               1         92934.41       0         0
# 84           1               1        374720.50       1         1
# 85           1               1        116537.96       0         0
# 88           1               1         52952.24       0         0
# 92           1               2        230000.82       0         0
#
#      Satisfaction Score  Point Earned  Card Type_DIAMOND  Card Type_GOLD  \
# Age
# 18                   75         13427                  5              10
# 19                   90         17230                  4               7
# 20                  141         23452                 13              14
# 21                  162         31271                 14              11
# 22                  259         52864                 19              20
# ..                  ...           ...                ...             ...
# 83                    4           753                  1               0
# 84                    5          1376                  1               0
# 85                    2           542                  0               1
# 88                    1           627                  0               0
# 92                    8          1079                  0               0
#
#      Card Type_PLATINUM  Card Type_SILVER
# Age
# 18                    5                 2
# 19                   10                 6
# 20                    9                 4
# 21                   14                14
# 22                   21                24
# ..                  ...               ...
# 83                    0                 0
# 84                    0                 1
# 85                    0                 0
# 88                    1                 0
# 92                    1                 1
#
# [70 rows x 17 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# plt.hist(df['Age'],df['Complain'])


plt.bar(df['Age'],df['Point Earned'])
plt.xlabel('age')
plt.ylabel('points')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.scatter(df['Age'],df['Complain'])
plt.xlabel('age')
plt.ylabel('complain')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited  Complain  \
# 0          1               1        101348.88       1         1
# 1          0               1        112542.58       0         1
# 2          1               0        113931.57       1         1
# 3          0               0         93826.63       0         0
# 4          1               1         79084.10       0         0
#
#    Satisfaction Score  Point Earned  Card Type_DIAMOND  Card Type_GOLD  \
# 0                   2           464               True           False
# 1                   3           456               True           False
# 2                   3           377               True           False
# 3                   5           350              False            True
# 4                   5           425              False            True
#
#    Card Type_PLATINUM  Card Type_SILVER
# 0               False             False
# 1               False             False
# 2               False             False
# 3               False             False
# 4               False             False

# %%
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Complain', 'Satisfaction Score', 'Point Earned',
#        'Card Type_DIAMOND', 'Card Type_GOLD', 'Card Type_PLATINUM',
#        'Card Type_SILVER'],
#       dtype='object')

# %%
plt.hist(df['CreditScore'], bins=30, edgecolor='k')
plt.title('Distribution of Credit Scores')
plt.xlabel('Credit Score')
plt.ylabel('Frequency')
plt.show()

# %%
df['Geography'].value_counts().plot(kind='bar')
plt.title('Count of Customers by Geography')
plt.xlabel('Geography')
plt.ylabel('Count')
plt.show()

# %%
# Box plot of Balance by Geography
df.boxplot(column='Balance', by='Geography')
plt.title('Balance Distribution by Geography')
plt.xlabel('Geography')
plt.ylabel('Balance')
plt.show()

# %%
# Scatter plot of Credit Score vs. Balance
plt.scatter(df['CreditScore'], df['Balance'])
plt.title('Credit Score vs. Balance')
plt.xlabel('Credit Score')
plt.ylabel('Balance')
plt.show()

# %%
# Pie chart of Gender distribution
df['Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
# Line plot of Age vs. Estimated Salary
df.groupby('Age')['EstimatedSalary'].mean().plot(kind='line')
plt.title('Average Estimated Salary by Age')
plt.xlabel('Age')
plt.ylabel('Average Estimated Salary')
plt.show()

# %%
# Heatmap of correlations
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.countplot(x='Card Type_DIAMOND', data=df)
plt.title('Count of Diamond Card Holders')
plt.xlabel('Diamond Card Holder')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='Card Type_GOLD', data=df)
plt.title('Count of Gold Card Holders')
plt.xlabel('GOld Card Holder')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='Card Type_DIAMOND', data=df)
plt.title('Count of Diamond Card Holders')
plt.xlabel('Diamond Card Holder')
plt.ylabel('Count')
plt.show()

# %%
df['Card Type_DIAMOND'].sum()
# Out:
# 2507

# %%
df['Card Type_GOLD'].sum()
# Out:
# 2502

# %%
df['Card Type_PLATINUM'].sum()
# Out:
# 2495

# %%
df['Card Type_SILVER'].sum()
# Out:
# 2496

# %%
### standardisation

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df.head()
# Out:
#    CreditScore  Geography    Gender       Age    Tenure   Balance  \
# 0    -0.326221  -0.901886 -1.095988  0.293517 -1.041760 -1.225848
# 1    -0.440036   1.515067 -1.095988  0.198164 -1.387538  0.117350
# 2    -1.536794  -0.901886 -1.095988  0.293517  1.032908  1.333053
# 3     0.501521  -0.901886 -1.095988  0.007457 -1.387538 -1.225848
# 4     2.063884   1.515067 -1.095988  0.388871 -1.041760  0.785728
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary    Exited  \
# 0      -0.911583   0.646092        0.970243         0.021886  1.976555
# 1      -0.911583  -1.547768        0.970243         0.216534 -0.505931
# 2       2.527057   0.646092       -1.030670         0.240687  1.976555
# 3       0.807737  -1.547768       -1.030670        -0.108918 -0.505931
# 4      -0.911583   0.646092        0.970243        -0.365276 -0.505931
#
#    Complain  Satisfaction Score  Point Earned  Card Type_DIAMOND  \
# 0  1.972908           -0.721130     -0.630839           1.728824
# 1  1.972908           -0.009816     -0.666251           1.728824
# 2  1.972908           -0.009816     -1.015942           1.728824
# 3 -0.506866            1.412812     -1.135457          -0.578428
# 4 -0.506866            1.412812     -0.803472          -0.578428
#
#    Card Type_GOLD  Card Type_PLATINUM  Card Type_SILVER
# 0       -0.577658            -0.57658         -0.576734
# 1       -0.577658            -0.57658         -0.576734
# 2       -0.577658            -0.57658         -0.576734
# 3        1.731128            -0.57658         -0.576734
# 4        1.731128            -0.57658         -0.576734

# %%
df['Card Type_DIAMOND'] = df['Card Type_DIAMOND'].astype('int')

# %%
df['Card Type_GOLD'] = df['Card Type_GOLD'].astype('int')

# %%
df['Card Type_PLATINUM'] = df['Card Type_PLATINUM'].astype('int')

# %%
df['Card Type_SILVER'] = df['Card Type_SILVER'].astype('int')
df.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited', 'Complain', 'Satisfaction Score', 'Point Earned',
#        'Card Type_DIAMOND', 'Card Type_GOLD', 'Card Type_PLATINUM',
#        'Card Type_SILVER'],
#       dtype='object')

# %% [markdown]
# ## making a model for prediction

# %%
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %%
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, Flatten

X = df.drop('Exited',axis=1)
y = df['Exited']

# %%
X_train , X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
len(X_train.columns)
# Out:
# 17

# %%
y_train
# Out:
# 50      0
# 7570    1
# 7091    1
# 3734    0
# 6229    0
#        ..
# 4790    0
# 9575    0
# 9451    1
# 2987    1
# 7465    0
# Name: Exited, Length: 8000, dtype: int64

# %%
model = keras.Sequential([
    keras.layers.Dense(20, input_shape=(17,), activation='relu'),
    keras.layers.Dense(1, activation='sigmoid'),
])

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 20)                360
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 381
# Trainable params: 381
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 250
training_history = model.fit(X_train,y_train,epochs=epochs,validation_data=(X_test,y_test))
# Out:
# Epoch 1/250
# 250/250 [==============================] - 3s 3ms/step - loss: 350.1792 - accuracy: 0.6784 - val_loss: 75.4443 - val_accuracy: 0.4700
# Epoch 2/250
# 250/250 [==============================] - 1s 2ms/step - loss: 65.4921 - accuracy: 0.6777 - val_loss: 30.9751 - val_accuracy: 0.7400
# Epoch 3/250
# 250/250 [==============================] - 1s 2ms/step - loss: 43.6426 - accuracy: 0.6800 - val_loss: 46.6605 - val_accuracy: 0.8100
# Epoch 4/250
# 250/250 [==============================] - 1s 2ms/step - loss: 48.1899 - accuracy: 0.6823 - val_loss: 87.0771 - val_accuracy: 0.5645
# Epoch 5/250
# 250/250 [==============================] - 1s 2ms/step - loss: 38.4258 - accuracy: 0.6766 - val_loss: 15.2369 - val_accuracy: 0.7395
# Epoch 6/250
# 250/250 [==============================] - 1s 2ms/step - loss: 35.9427 - accuracy: 0.6844 - val_loss: 18.6382 - val_accuracy: 0.7930
# Epoch 7/250
# Epoch 238/250
# 250/250 [==============================] - 1s 2ms/step - loss: 6.4784 - accuracy: 0.8559 - val_loss: 17.2773 - val_accuracy: 0.8235
# Epoch 239/250
# 250/250 [==============================] - 0s 2ms/step - loss: 6.8161 - accuracy: 0.8788 - val_loss: 18.0778 - val_accuracy: 0.7295
# Epoch 240/250
# 250/250 [==============================] - 0s 2ms/step - loss: 5.2511 - accuracy: 0.8610 - val_loss: 2.2525 - val_accuracy: 0.9240
# Epoch 241/250
# 250/250 [==============================] - 0s 2ms/step - loss: 9.2030 - accuracy: 0.8495 - val_loss: 12.8050 - val_accuracy: 0.8540
# Epoch 242/250
# 250/250 [==============================] - 1s 2ms/step - loss: 6.4124 - accuracy: 0.8550 - val_loss: 3.1521 - val_accuracy: 0.9140
# Epoch 243/250
# 250/250 [==============================] - 0s 2ms/step - loss: 2.8473 - accuracy: 0.9079 - val_loss: 1.2133 - val_accuracy: 0.9260
# Epoch 244/250
# 250/250 [==============================] - 0s 2ms/step - loss: 6.7671 - accuracy: 0.8450 - val_loss: 0.5850 - val_accuracy: 0.9650
# Epoch 245/250
# 250/250 [==============================] - 0s 2ms/step - loss: 6.9551 - accuracy: 0.8406 - val_loss: 2.0405 - val_accuracy: 0.9260
# Epoch 246/250
# 250/250 [==============================] - 1s 2ms/step - loss: 7.8357 - accuracy: 0.8378 - val_loss: 0.1909 - val_accuracy: 0.9780
# Epoch 247/250
# 250/250 [==============================] - 0s 2ms/step - loss: 4.7117 - accuracy: 0.8776 - val_loss: 6.1821 - val_accuracy: 0.7615
# Epoch 248/250
# 250/250 [==============================] - 0s 2ms/step - loss: 11.3150 - accuracy: 0.8355 - val_loss: 8.5874 - val_accuracy: 0.8855
# Epoch 249/250
# 250/250 [==============================] - 0s 2ms/step - loss: 7.9213 - accuracy: 0.8508 - val_loss: 10.2214 - val_accuracy: 0.8475
# Epoch 250/250
# 250/250 [==============================] - 1s 2ms/step - loss: 10.5832 - accuracy: 0.8166 - val_loss: 0.4409 - val_accuracy: 0.9665

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
model.evaluate(X_test,y_test)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.4409 - accuracy: 0.9665
# [0.4409470558166504, 0.9664999842643738]

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 63/63 [==============================] - 0s 760us/step

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1626
#            1       0.94      0.87      0.91       374
#
#     accuracy                           0.97      2000
#    macro avg       0.96      0.93      0.94      2000
# weighted avg       0.97      0.97      0.97      2000

# %%
cm = confusion_matrix(y_test, y_pred)

# Plot the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

# %%
# import tensorboard

# %load_ext tensorboard

# %tensorboard --logdir logs
# %reload_ext tensorboard

# %%
epochs = range(1,251,1)
epochs = np.array(epochs)

# %%
plt.plot(epochs,training_history.history['accuracy'],color = 'blue',label='training')
plt.plot(epochs, training_history.history['val_accuracy'], color='orange', label='Validation Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
plt.plot(epochs,training_history.history['loss'],color = 'blue',label='training')
plt.plot(epochs,training_history.history['val_loss'],color='orange',label = 'validation')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model.save('churn_model.h5')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined
